# %%
# @name neo4j_import
# @description notebook to build the Neo4j graph 
# @author Núria Queralt Rosinach
# @date 20-10-2020

# %% [markdown]
# # Cytokines data import into Neo4j graph
#
# ### Steps
#
#     1. Read data, URIs (id mappings) and semantic model types (owl)
#     2. Prepare graph files for Neo4j
#     3. Import into Neo4j server
#
# ### Import

# %%
import pandas as pd
import rdflib
from hashlib import md5

# %% [markdown]
# ### Workflow
# #### 1. Read data,  semantic model, id_mapping

# %%
# read cytokines data
data_file = '/home/nur/workspace/beat-covid/fair-data-model/cytokine/synthetic-data/BEAT-COVID1_excel_export_2020-05-28_Luminex_synthetic-data.csv'
data = pd.read_csv(data_file, sep='\t')
print("Citokines data dimension: {}".format(data.shape))
data.head(5)
# Out:
# Citokines data dimension: (9, 141)
#    record_id institute_abbreviation record_creation_date   order  \
# 0  201708869                   LUMC  26-05-2020 15:31:31  BEATVR
# 1  201903364                   LUMC  26-05-2020 15:42:21  BEATMA
# 2  201803814                   LUMC  26-05-2020 15:45:16  BEATWO
# 3  202000138                   LUMC  26-05-2020 15:38:41  BEATAD
# 4  202000131                   LUMC  26-05-2020 15:42:26  BEATWO
#
#   date_sampling  ward  age   beat_id  clinical_id lum_date_meas  ...  \
# 0    08-05-2020  ICUQ   59  BEAT-018    1100207.0    04-05-2020  ...
# 1    01-05-2020  VIG1   30  BEAT-007    1100125.0    22-04-2020  ...
# 2    04-05-2020  LOKL   54  BEAT-026    1100154.0    11-05-2020  ...
# 3    06-05-2020  KVVL   58  BEAT-001          NaN    04-05-2020  ...
# 4    04-05-2020  KVVL   54  BEAT-023    1100103.0    25-05-2020  ...
#
#   lum_sTNFR1_3  lum_sTNFR2_3  lum_TSLP_3 lum_TWEAK_3  lum_IL17F_4 lum_IL21_4  \
# 0          963           263       OOR <         329        OOR <      OOR <
# 1         1230           272          10         111        OOR <      OOR <
# 2         1046           335           4          76        OOR <      OOR <
# 3          997           269           9         123        OOR <      OOR <
# 4         1374           332           9         181        OOR <      OOR <
#
#    lum_IL23_4  lum_IL25_4  lum_IL31_4  lum_IL33_4
# 0       OOR <       OOR <       OOR <         597
# 1       OOR <           5       OOR <       OOR <
# 2       OOR <       OOR <       OOR <       OOR <
# 3       OOR <       OOR <       OOR <       OOR <
# 4       OOR <       OOR <       OOR <         794
#
# [5 rows x 141 columns]

# %%
# read id_mapping csv file
id_file = '/home/nur/workspace/beat-covid/fair-data-model/cytokine/id-mapping/cytokines_lab_terms_pilot_mapping_clean.csv'
mappings = pd.read_csv(id_file, sep=',')
print("Citokines data dimension: {}".format(mappings.shape))
mappings.head(5)
# Out:
# Citokines data dimension: (103, 9)
#   lab data (ensembl gene name)     ensembl gene uniprot  \
# 0                       CX3CL1  ENSG00000006210  P78423
# 1                        CCL26  ENSG00000006606  Q9Y258
# 2                         IL32  ENSG00000008517  P24001
# 3                          HGF  ENSG00000019991  P14210
# 4                        CXCL2  ENSG00000081041  P19875
#
#                                   ncit protein  \
# 0   http://purl.obolibrary.org/obo/NCIT_C20489
# 1   http://purl.obolibrary.org/obo/NCIT_C28739
# 2  http://purl.obolibrary.org/obo/NCIT_C127926
# 3   http://purl.obolibrary.org/obo/NCIT_C20428
# 4   http://purl.obolibrary.org/obo/NCIT_C20474
#
#                                      ncit gene  \
# 0   http://purl.obolibrary.org/obo/NCIT_C24796
# 1   http://purl.obolibrary.org/obo/NCIT_C24780
# 2  http://purl.obolibrary.org/obo/NCIT_C127924
# 3   http://purl.obolibrary.org/obo/NCIT_C24467
# 4   http://purl.obolibrary.org/obo/NCIT_C18426
#
#   ncit measurement (protein) = PROCESS or ACTIVITY  \
# 0      http://purl.obolibrary.org/obo/NCIT_C161361
# 1       http://purl.obolibrary.org/obo/NCIT_C81954
# 2       http://purl.obolibrary.org/obo/NCIT_C74830
# 3      http://purl.obolibrary.org/obo/NCIT_C135426
# 4       http://purl.obolibrary.org/obo/NCIT_C81867
#
#   Clinical Measurement Ontology (CMO) (protein) = Measurement value which is the result of a process/activity  \
# 0               http://www.ebi.ac.uk/efo/EFO_0009419
# 1               http://www.ebi.ac.uk/efo/EFO_0008122
# 2         http://purl.obolibrary.org/obo/CMO_0001925
# 3               http://www.ebi.ac.uk/efo/EFO_0006903
# 4         http://purl.obolibrary.org/obo/NCIT_C74804
#
#    Unnamed: 7  Unnamed: 8
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4         NaN         NaN

# %%
# read semantic model
owl_file = '/home/nur/workspace/beat-covid/fair-data-model/cytokine/owl/cytokine_semantic_model.owl'
owl = rdflib.Graph()
owl.load(owl_file)
print("* The ontology has {} statements.".format(len(owl)))
import pprint
for stmt in owl:
    pprint.pprint(stmt)
# Out:
# * The ontology has 583 statements.
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_001049'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000132'),
#  rdflib.term.URIRef('http://purl.org/dc/terms/description'),
#  rdflib.term.Literal('has participant is a relation that describes the participation of the object in the (processual) subject.', lang='en'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000229'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'),
#  rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000004'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000008'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#domain'),
#  rdflib.term.URIRef('http://semanticscience.org/resource/SIO_001024'))
# (rdflib.term.URIRef('http://www.w3.org/ns/prov#wasInformedBy'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#domain'),
#  rdflib.term.URIRef('http://purl.obolibrary.org/obo/OBI_0000070'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000776'),
#  rdflib.term.URIRef('http://purl.org/dc/terms/description'),
#  rdflib.term.Literal('an object is an entity that is wholly identifiable at any instant of time during which it exists.', lang='en'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_010079'),
#  rdflib.term.URIRef('http://purl.org/dc/elements/1.1/identifier'),
#  rdflib.term.Literal('SIO_010079'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000221'),
#  rdflib.term.URIRef('http://purl.org/dc/terms/description'),
#  rdflib.term.Literal('has unit is a relation between a quantity and the unit it is a multiple of.', lang='en'))
# (rdflib.term.BNode('N809dd86ad1e9466e836e178361283588'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#first'),
#  rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000688'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000229'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#domain'),
#  rdflib.term.URIRef('http://semanticscience.org/resource/SIO_001049'))
# (rdflib.term.URIRef('http://purl.org/beat-covid/cytokines-semantic-model.owl'),
#  rdflib.term.URIRef('http://purl.org/dc/elements/1.1/creator'),
#  rdflib.term.URIRef('http://orcid.org/0000−0003−1795−5930'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/RO_0001025'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'),
#  rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000688'))
# (rdflib.term.URIRef('http://purl.org/beat-covid/cytokines-semantic-model#clinical_id'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_010056'),
#  rdflib.term.URIRef('http://purl.org/dc/elements/1.1/identifier'),
#  rdflib.term.Literal('SIO_010056'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000006'),
#  rdflib.term.URIRef('http://purl.org/dc/terms/description'),
#  rdflib.term.Literal('a process is an entity that is identifiable only through the unfolding of time, has temporal parts, and unless otherwise specified/predicted, cannot be identified from any instant of time in which it exists.', lang='en'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000008'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'),
#  rdflib.term.URIRef('http://semanticscience.org/resource/SIO_001013'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_001210'),
#  rdflib.term.URIRef('http://purl.org/dc/terms/description'),
#  rdflib.term.Literal('positive is an assertional qualifier that expresses the validity or truth of a basic assertion, e.g. in a medical examination the observation is the presence of a trait or phenotype.', lang='en'))
# (rdflib.term.URIRef('http://www.bioassayontology.org/bao#BAO_0002854'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'),
#  rdflib.term.URIRef('http://purl.obolibrary.org/obo/OBI_0000070'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_001403'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'),
#  rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000992'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000300'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#domain'),
#  rdflib.term.URIRef('http://purl.obolibrary.org/obo/IAO_0000109'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_010043'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000115'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('identifier', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/OBI_0000070'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/IAO_0000109'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/OBI_0000968'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://purl.org/dc/terms/identifier'),
#  rdflib.term.URIRef('http://purl.org/dc/terms/description'),
#  rdflib.term.Literal('an unambiguous reference to the resource within a given context.', lang='en'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_001050'),
#  rdflib.term.URIRef('http://purl.org/dc/elements/1.1/identifier'),
#  rdflib.term.Literal('SIO_001050'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000642'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('is base for', lang='en'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000016'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('role', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/RO_0001025'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('located in', lang='en'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000672'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#ObjectProperty'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000300'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#DatatypeProperty'))
# (rdflib.term.BNode('Nd4325b3b68b648ea9090204e55183eec'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#first'),
#  rdflib.term.URIRef('http://semanticscience.org/resource/SIO_001013'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000300'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subPropertyOf'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#topDataProperty'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/IAO_0000219'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.BNode('Nad820c58dfeb4dc4851ae314a425208f'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#first'),
#  rdflib.term.URIRef('http://purl.org/beat-covid/cytokines-semantic-model#record_id'))
# (rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://purl.org/dc/terms/identifier'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#Literal'))
# (rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('label', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/IAO_0000003'),
#  rdflib.term.URIRef('http://purl.org/dc/elements/1.1/identifier'),
#  rdflib.term.Literal('IAO_0000003'))
# (rdflib.term.BNode('N77b9e56e30d34173909a9cf4ee0db6f1'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#first'),
#  rdflib.term.URIRef('http://semanticscience.org/resource/SIO_010056'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000340'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000688'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_001403'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'),
#  rdflib.term.URIRef('http://semanticscience.org/resource/SIO_001289'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000016'),
#  rdflib.term.URIRef('http://purl.org/dc/terms/description'),
#  rdflib.term.Literal('a role is a realizable entity that describes behaviours, rights and obligations of an entity in some particular circumstance.', lang='en'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000356'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'),
#  rdflib.term.URIRef('http://purl.obolibrary.org/obo/OBI_0000070'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_010056'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_001289'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('never', lang='en'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000960'),
#  rdflib.term.URIRef('http://purl.org/dc/elements/1.1/identifier'),
#  rdflib.term.Literal('SIO_000960'))
# (rdflib.term.URIRef('http://purl.org/dc/terms/conformsTo'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'),
#  rdflib.term.URIRef('http://purl.obolibrary.org/obo/OBI_0000272'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000642'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'),
#  rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000340'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/IAO_0000219'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#domain'),
#  rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000115'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000628'),
#  rdflib.term.URIRef('http://purl.org/dc/elements/1.1/identifier'),
#  rdflib.term.Literal('SIO_000628'))
# (rdflib.term.URIRef('http://purl.org/dc/terms/Agent'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000356'),
#  rdflib.term.URIRef('http://purl.org/dc/terms/description'),
#  rdflib.term.Literal('the role of a patient is realized in medical examination.', lang='en'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000672'),
#  rdflib.term.URIRef('http://purl.org/dc/terms/description'),
#  rdflib.term.Literal('a relation between an identifier and an entity.', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/BFO_0000050'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#ReflexiveProperty'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000228'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'),
#  rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000715'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000793'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'),
#  rdflib.term.URIRef('http://purl.obolibrary.org/obo/NCIT_C25164'))
# (rdflib.term.BNode('Ne68ce8df19e8417d8466ec117e6420f5'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#rest'),
#  rdflib.term.BNode('N471eae6918ad46caaa10ed1ae55875f2'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000356'),
#  rdflib.term.URIRef('http://purl.org/dc/elements/1.1/identifier'),
#  rdflib.term.Literal('SIO_000356'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000139'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'),
#  rdflib.term.URIRef('http://purl.org/dc/terms/Agent'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_001210'),
#  rdflib.term.URIRef('http://purl.org/dc/elements/1.1/identifier'),
#  rdflib.term.Literal('SIO_001210'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_001292'),
#  rdflib.term.URIRef('http://purl.org/dc/terms/description'),
#  rdflib.term.Literal('always indicates that the event occurs at all times.', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/BFO_0000050'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subPropertyOf'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#topObjectProperty'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_010035'),
#  rdflib.term.URIRef('http://purl.org/dc/terms/description'),
#  rdflib.term.Literal('a gene is part of a nucleic acid that contains all the necessary elements to encode a functional transcript.', lang='en'))
# (rdflib.term.BNode('Ne182b505035746e2b469ace4a4ad41ca'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#rest'),
#  rdflib.term.BNode('Nbb31426d886d45d9aeecac00cd44d303'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000230'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('has input', lang='en'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000642'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_001211'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('negative', lang='en'))
# (rdflib.term.URIRef('http://purl.org/beat-covid/cytokines-semantic-model#clinical_id'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('Clinical_ID', lang='en'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000356'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('is realized in', lang='en'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_001403'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'),
#  rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000960'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000628'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.BNode('Na78c4068cb0547ef88e894c66fae8b5e'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#first'),
#  rdflib.term.URIRef('http://purl.obolibrary.org/obo/OBI_0000070'))
# (rdflib.term.URIRef('http://purl.org/dc/elements/1.1/contributor'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#AnnotationProperty'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000793'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://purl.org/beat-covid/cytokines-semantic-model#beat_covid_id'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000008'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#domain'),
#  rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000715'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000688'),
#  rdflib.term.URIRef('http://purl.org/dc/elements/1.1/identifier'),
#  rdflib.term.Literal('SIO_000688'))
# (rdflib.term.URIRef('http://purl.org/dc/terms/date'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'),
#  rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#dateTime'))
# (rdflib.term.BNode('Na78c4068cb0547ef88e894c66fae8b5e'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#rest'),
#  rdflib.term.BNode('N2ea419ac09694a759ae74a79c7eb6bad'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000011'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#domain'),
#  rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000340'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000715'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'),
#  rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000016'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000005'),
#  rdflib.term.URIRef('http://purl.org/dc/terms/description'),
#  rdflib.term.Literal('a quality is an attribute that is intrinsically associated with its bearer (or its parts), but whose presence/absence and observed/measured value may vary.', lang='en'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000793'),
#  rdflib.term.URIRef('http://purl.org/dc/terms/description'),
#  rdflib.term.Literal('measured at is a relation between a measurement value and the time measurement.', lang='en'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_010079'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('is encoded by', lang='en'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000960'),
#  rdflib.term.URIRef('http://purl.org/dc/terms/description'),
#  rdflib.term.Literal('real is the quality of an entity that exists in real space and time.', lang='en'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000229'),
#  rdflib.term.URIRef('http://purl.org/dc/terms/description'),
#  rdflib.term.Literal('has output is a relation between a process and an entity, where the entity is present at the end of the process.', lang='en'))
# (rdflib.term.URIRef('http://www.w3.org/ns/prov#wasInformedBy'),
#  rdflib.term.URIRef('http://purl.org/dc/terms/description'),
#  rdflib.term.Literal('was informed by is a relation between two processes where one process communicates to another process. Communication is the exchange of an entity by two activities, one activity using the entity generated by the other.', lang='en'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_010003'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('organ', lang='en'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000960'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'),
#  rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000005'))
# (rdflib.term.BNode('N809dd86ad1e9466e836e178361283588'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#rest'),
#  rdflib.term.BNode('N3fadca0d345341b28f73e43533148c77'))
# (rdflib.term.URIRef('http://purl.org/beat-covid/cytokines-semantic-model#clinical_id'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'),
#  rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000115'))
# (rdflib.term.URIRef('http://purl.org/dc/terms/description'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#AnnotationProperty'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000992'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.BNode('N154f283c54f44dd2917ec942210d12de'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#first'),
#  rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000115'))
# (rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'),
#  rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/OBI_0000070'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'),
#  rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000006'))
# (rdflib.term.BNode('N1d2daf456ce84898b48bcaea6fcd46a1'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#first'),
#  rdflib.term.URIRef('http://purl.org/beat-covid/cytokines-semantic-model#clinical_id'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000498'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://purl.org/beat-covid/cytokines-semantic-model.owl'),
#  rdflib.term.URIRef('http://purl.org/dc/elements/1.1/creator'),
#  rdflib.term.URIRef('http://orcid.org/0000-0003-0169-8159'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000011'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'),
#  rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000498'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/OBI_0000968'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_001211'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'),
#  rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000005'))
# (rdflib.term.URIRef('http://purl.org/dc/terms/rights'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#AnnotationProperty'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000291'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#domain'),
#  rdflib.term.URIRef('http://purl.obolibrary.org/obo/OBI_0000070'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000132'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000642'),
#  rdflib.term.URIRef('http://purl.org/dc/terms/description'),
#  rdflib.term.Literal('is base for is a relation between a quality and the realizable entity that it is the basis for.', lang='en'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000011'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('is attribute of', lang='en'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000672'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('is identifier for', lang='en'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000229'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#domain'),
#  rdflib.term.URIRef('http://semanticscience.org/resource/SIO_001024'))
# (rdflib.term.URIRef('http://purl.org/dc/terms/license'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#AnnotationProperty'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000004'),
#  rdflib.term.URIRef('http://purl.org/dc/elements/1.1/identifier'),
#  rdflib.term.Literal('SIO_000004'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000291'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000011'),
#  rdflib.term.URIRef('http://purl.org/dc/terms/description'),
#  rdflib.term.Literal('is attribute of is a relation that associates an attribute with an entity where an attribute is an intrinsic characteristic such as a quality, capability, disposition, function, or is an externally derived attribute determined from some descriptor (e.g. a quantity, position, label/identifier) either directly or indirectly through generalization of entities of the same type.', lang='en'))
# (rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.URIRef('http://purl.org/dc/elements/1.1/identifier'),
#  rdflib.term.Literal('label'))
# (rdflib.term.BNode('Nbed9b2ba0d3f4d7fb0ea8f6f084fca1a'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#rest'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#nil'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000498'),
#  rdflib.term.URIRef('http://purl.org/dc/terms/description'),
#  rdflib.term.Literal('a person is an object that has certain capacities or attributes constituting personhood.', lang='en'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_010056'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_001050'),
#  rdflib.term.URIRef('http://purl.org/dc/terms/description'),
#  rdflib.term.Literal('a sample is a limited quantity of something (e.g. an individual or set of individuals from a population, or a portion of a substance) to be used for testing, analysis, inspection, investigation, demonstration, or trial use.', lang='en'))
# (rdflib.term.BNode('Nb2510cab567146819f654a37dcf839ca'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#rest'),
#  rdflib.term.BNode('N8c87bd933b4840a688bb9d8297309872'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/BFO_0000050'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://purl.org/dc/terms/identifier'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subPropertyOf'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#topDataProperty'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/NCIT_C48906'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/NCIT_C25164'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000672'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'),
#  rdflib.term.URIRef('http://semanticscience.org/resource/SIO_001050'))
# (rdflib.term.BNode('N8c87bd933b4840a688bb9d8297309872'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#first'),
#  rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000005'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_001024'),
#  rdflib.term.URIRef('http://purl.org/dc/terms/description'),
#  rdflib.term.Literal('a medical procedure is a procedure to identify, examine, alleviate or eliminate an undesirable biological disease or disorder.', lang='en'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000016'),
#  rdflib.term.URIRef('http://purl.org/dc/elements/1.1/identifier'),
#  rdflib.term.Literal('SIO_000016'))
# (rdflib.term.URIRef('http://purl.org/dc/terms/date'),
#  rdflib.term.URIRef('http://purl.org/dc/elements/1.1/identifier'),
#  rdflib.term.Literal('date'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/OBI_0000070'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/IAO_0000109'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000221'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000230'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subPropertyOf'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#topObjectProperty'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_010079'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subPropertyOf'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#topObjectProperty'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/IAO_0000219'),
#  rdflib.term.URIRef('http://purl.org/dc/elements/1.1/identifier'),
#  rdflib.term.Literal('IAO_0000219'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/RO_0002091'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#ObjectProperty'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/NCIT_C21541'),
#  rdflib.term.URIRef('http://purl.org/dc/elements/1.1/identifier'),
#  rdflib.term.Literal('NCIT_C21541'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/BFO_0000050'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#domain'),
#  rdflib.term.URIRef('http://semanticscience.org/resource/SIO_010043'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/OBI_0000070'),
#  rdflib.term.URIRef('http://purl.org/dc/terms/description'),
#  rdflib.term.Literal('a planned process with the objective to produce information about the material entity that is the evaluant, by physically examining it or its proxies.', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/NCIT_C21541'),
#  rdflib.term.URIRef('http://purl.org/dc/terms/description'),
#  rdflib.term.Literal('the buildings and organizations where healthcare services are provided, e.g. ward.', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/NCIT_C25164'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('date', lang='en'))
# (rdflib.term.BNode('Nbb31426d886d45d9aeecac00cd44d303'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#rest'),
#  rdflib.term.BNode('Ndeafa4cd4e5349899f4127172cf6e5f7'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/RO_0002091'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subPropertyOf'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#topObjectProperty'))
# (rdflib.term.URIRef('http://purl.org/beat-covid/cytokines-semantic-model#beat_covid_id'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'),
#  rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000115'))
# (rdflib.term.BNode('N98fd0d569dcc4b75ba7ddf54fe6ea289'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#rest'),
#  rdflib.term.BNode('Nc36009aa51a94cecadc966dc99d9a528'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000115'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/RO_0002091'),
#  rdflib.term.URIRef('http://purl.org/dc/terms/description'),
#  rdflib.term.Literal('starts during is a relation between a process and an information content entity that states a point or period of time when the process has to start. X starts_during Y iff: (start(Y) before_or_simultaneous_with start(X)) AND (start(X) before_or_simultaneous_with end(Y)), e.g. the patient sampling starts during what is stated in the order done by the medical doctor.', lang='en'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000221'),
#  rdflib.term.URIRef('http://purl.org/dc/elements/1.1/identifier'),
#  rdflib.term.Literal('SIO_000221'))
# (rdflib.term.URIRef('http://www.bioassayontology.org/bao#BAO_0002854'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000006'),
#  rdflib.term.URIRef('http://purl.org/dc/elements/1.1/identifier'),
#  rdflib.term.Literal('SIO_000006'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000340'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000688'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_001024'),
#  rdflib.term.URIRef('http://purl.org/dc/elements/1.1/identifier'),
#  rdflib.term.Literal('SIO_001024'))
# (rdflib.term.URIRef('http://purl.org/beat-covid/cytokines-semantic-model.owl'),
#  rdflib.term.URIRef('http://purl.org/dc/elements/1.1/contributor'),
#  rdflib.term.URIRef('http://orcid.org/0000−0002−8691−772X'))
# (rdflib.term.BNode('N154f283c54f44dd2917ec942210d12de'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#rest'),
#  rdflib.term.BNode('Ne66eddedcb704ef8a48e96c1e4f745da'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000229'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#ObjectProperty'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/IAO_0000109'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('measurement datum', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/RO_0001025'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subPropertyOf'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#topObjectProperty'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_010079'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#ObjectProperty'))
# (rdflib.term.BNode('N2ea419ac09694a759ae74a79c7eb6bad'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#first'),
#  rdflib.term.URIRef('http://semanticscience.org/resource/SIO_001024'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_001210'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'),
#  rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000005'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/RO_0001025'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#domain'),
#  rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000715'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_001013'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('age', lang='en'))
# (rdflib.term.BNode('N180707e2e19849d0b39b7a90f92b0ae7'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#rest'),
#  rdflib.term.BNode('Nad22356e8d5d43bea5a1a03b04b96f88'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_010003'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#disjointWith'),
#  rdflib.term.URIRef('http://semanticscience.org/resource/SIO_010043'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000228'),
#  rdflib.term.URIRef('http://purl.org/dc/terms/description'),
#  rdflib.term.Literal('has role is a relation between an entity and a role that it bears.', lang='en'))
# (rdflib.term.BNode('N0504dc6b9398485b90c03d24cbcb21be'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#first'),
#  rdflib.term.URIRef('http://semanticscience.org/resource/SIO_001049'))
# (rdflib.term.URIRef('http://purl.org/dc/terms/identifier'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('identifier', lang='en'))
# (rdflib.term.URIRef('http://purl.org/beat-covid/cytokines-semantic-model#record_id'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#isDefinedBy'),
#  rdflib.term.URIRef('http://purl.org/beat-covid/cytokines-semantic-model.owl'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000229'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'),
#  rdflib.term.URIRef('http://semanticscience.org/resource/SIO_001050'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_010035'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000229'),
#  rdflib.term.URIRef('http://purl.org/dc/elements/1.1/identifier'),
#  rdflib.term.Literal('SIO_000229'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/RO_0001025'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#ObjectProperty'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/BFO_0000050'),
#  rdflib.term.URIRef('http://purl.org/dc/elements/1.1/identifier'),
#  rdflib.term.Literal('BFO_0000050'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/BFO_0000050'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#domain'),
#  rdflib.term.URIRef('http://purl.obolibrary.org/obo/NCIT_C21541'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_001211'),
#  rdflib.term.URIRef('http://purl.org/dc/terms/description'),
#  rdflib.term.Literal('negative is an assertional qualifier that expresses the falsity or lack of truth of a basic assertion, e.g. in a medical examination the observation is the absence of a trait or phenotype.', lang='en'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_001403'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('is associated with', lang='en'))
# (rdflib.term.BNode('Nc36009aa51a94cecadc966dc99d9a528'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#first'),
#  rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000992'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/IAO_0000219'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'),
#  rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000016'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000642'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#domain'),
#  rdflib.term.URIRef('http://semanticscience.org/resource/SIO_010056'))
# (rdflib.term.URIRef('http://purl.org/dc/terms/conformsTo'),
#  rdflib.term.URIRef('http://purl.org/dc/elements/1.1/identifier'),
#  rdflib.term.Literal('conformsTo'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_010035'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('gene', lang='en'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_010079'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'),
#  rdflib.term.URIRef('http://semanticscience.org/resource/SIO_010035'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000216'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('has measurement value', lang='en'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000217'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#domain'),
#  rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000498'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000291'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('has target', lang='en'))
# (rdflib.term.URIRef('http://purl.org/dc/terms/identifier'),
#  rdflib.term.URIRef('http://purl.org/dc/elements/1.1/identifier'),
#  rdflib.term.Literal('identifier'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_001289'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000776'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://purl.org/dc/terms/date'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000498'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.BNode('N77b9e56e30d34173909a9cf4ee0db6f1'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#rest'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#nil'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/RO_0001025'),
#  rdflib.term.URIRef('http://purl.org/dc/elements/1.1/identifier'),
#  rdflib.term.Literal('RO_0001025'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/NCIT_C25164'),
#  rdflib.term.URIRef('http://purl.org/dc/terms/description'),
#  rdflib.term.Literal('the particular day, month and year an event has happened or will happen.', lang='en'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000356'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'),
#  rdflib.term.URIRef('http://semanticscience.org/resource/SIO_001049'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000008'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subPropertyOf'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#topObjectProperty'))
# (rdflib.term.URIRef('http://purl.org/beat-covid/cytokines-semantic-model#record_id'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('Record_ID', lang='en'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000139'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subPropertyOf'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#topObjectProperty'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000228'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#domain'),
#  rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000498'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000008'),
#  rdflib.term.URIRef('http://purl.org/dc/elements/1.1/identifier'),
#  rdflib.term.Literal('SIO_000008'))
# (rdflib.term.BNode('N123f48b5e1d34fe99bb00f2a92344fc1'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#AllDisjointClasses'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000221'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('has unit', lang='en'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000011'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#ObjectProperty'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_001289'),
#  rdflib.term.URIRef('http://purl.org/dc/terms/description'),
#  rdflib.term.Literal('never refers to in none of the occasions.', lang='en'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000715'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('patient role', lang='en'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000230'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#domain'),
#  rdflib.term.URIRef('http://purl.obolibrary.org/obo/OBI_0000070'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000221'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#domain'),
#  rdflib.term.URIRef('http://purl.obolibrary.org/obo/IAO_0000109'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000217'),
#  rdflib.term.URIRef('http://purl.org/dc/terms/description'),
#  rdflib.term.Literal('has quality is a relation between an entity and the quality that it bears.', lang='en'))
# (rdflib.term.URIRef('http://www.bioassayontology.org/bao#BAO_0002854'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('has bioassay type', lang='en'))
# (rdflib.term.URIRef('http://purl.org/beat-covid/cytokines-semantic-model.owl'),
#  rdflib.term.URIRef('http://purl.org/dc/terms/issued'),
#  rdflib.term.Literal('30-08-2020'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_001013'),
#  rdflib.term.URIRef('http://purl.org/dc/terms/description'),
#  rdflib.term.Literal('age is the length of time that a person has lived or a thing has existed.', lang='en'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000340'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('realizable entity', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/NCIT_C48906'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000008'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#ObjectProperty'))
# (rdflib.term.URIRef('http://purl.org/dc/terms/conformsTo'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#ObjectProperty'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/NCIT_C25164'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000132'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#domain'),
#  rdflib.term.URIRef('http://purl.obolibrary.org/obo/OBI_0000070'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_010003'),
#  rdflib.term.URIRef('http://purl.org/dc/terms/description'),
#  rdflib.term.Literal('an organ is a collection of tissues joined in structural unit to serve a common function.', lang='en'))
# (rdflib.term.URIRef('http://purl.org/beat-covid/cytokines-semantic-model.owl'),
#  rdflib.term.URIRef('http://purl.org/dc/terms/title'),
#  rdflib.term.Literal('Cytokines semantic model (CSM)', lang='en'))
# (rdflib.term.BNode('Nad820c58dfeb4dc4851ae314a425208f'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#rest'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#nil'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_001210'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('positive', lang='en'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_010079'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#domain'),
#  rdflib.term.URIRef('http://semanticscience.org/resource/SIO_010043'))
# (rdflib.term.URIRef('http://purl.org/dc/terms/conformsTo'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subPropertyOf'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#topObjectProperty'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000216'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#ObjectProperty'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_001292'),
# ...
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subPropertyOf'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#topObjectProperty'))
# (rdflib.term.URIRef('http://purl.org/dc/terms/identifier'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#DatatypeProperty'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_010056'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('phenotype', lang='en'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000216'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#domain'),
#  rdflib.term.URIRef('http://semanticscience.org/resource/SIO_010043'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_001049'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000340'),
#  rdflib.term.URIRef('http://purl.org/dc/terms/description'),
#  rdflib.term.Literal('a realizable entity is an attribute that is exhibited under some condition and is realized in some process.', lang='en'))
# (rdflib.term.BNode('N471eae6918ad46caaa10ed1ae55875f2'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#first'),
#  rdflib.term.URIRef('http://purl.obolibrary.org/obo/NCIT_C48906'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000011'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000300'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/IAO_0000003'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('measurement unit label', lang='en'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000008'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#domain'),
#  rdflib.term.URIRef('http://purl.obolibrary.org/obo/OBI_0000070'))
# (rdflib.term.URIRef('http://purl.org/dc/terms/conformsTo'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#domain'),
#  rdflib.term.URIRef('http://purl.obolibrary.org/obo/OBI_0000070'))
# (rdflib.term.BNode('N34f9be062d14422cbd7097b8a35b29fa'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#AllDisjointClasses'))
# (rdflib.term.URIRef('http://purl.org/dc/terms/date'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#domain'),
#  rdflib.term.URIRef('http://semanticscience.org/resource/SIO_001050'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000291'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'),
#  rdflib.term.URIRef('http://semanticscience.org/resource/SIO_010043'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/OBI_0000070'),
#  rdflib.term.URIRef('http://purl.org/dc/elements/1.1/identifier'),
#  rdflib.term.Literal('OBI_0000070'))
# (rdflib.term.BNode('N4ca8f24785be4153b02b09ca7e893cd5'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#first'),
#  rdflib.term.URIRef('http://semanticscience.org/resource/SIO_001210'))
# (rdflib.term.URIRef('http://purl.org/dc/terms/Agent'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.BNode('N98fd0d569dcc4b75ba7ddf54fe6ea289'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#first'),
#  rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000960'))
# (rdflib.term.URIRef('http://purl.org/beat-covid/cytokines-semantic-model.owl'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#versionInfo'),
#  rdflib.term.Literal('1.0', lang='en'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/BFO_0000050'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#domain'),
#  rdflib.term.URIRef('http://semanticscience.org/resource/SIO_010003'))
# (rdflib.term.URIRef('http://purl.org/dc/terms/conformsTo'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.BNode('N0504dc6b9398485b90c03d24cbcb21be'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#rest'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#nil'))
# (rdflib.term.BNode('Ne66eddedcb704ef8a48e96c1e4f745da'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#first'),
#  rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000340'))
# (rdflib.term.BNode('Ndeafa4cd4e5349899f4127172cf6e5f7'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#rest'),
#  rdflib.term.BNode('Nb2510cab567146819f654a37dcf839ca'))
# (rdflib.term.URIRef('http://purl.org/beat-covid/cytokines-semantic-model#clinical_id'),
#  rdflib.term.URIRef('http://purl.org/dc/elements/1.1/identifier'),
#  rdflib.term.Literal('clinical_id'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000992'),
#  rdflib.term.URIRef('http://purl.org/dc/terms/description'),
#  rdflib.term.Literal('unsupported is an existence quality in which there is no evidence to support the existence of the entity in any world (real or hypothetical).', lang='en'))
# (rdflib.term.URIRef('http://purl.org/dc/elements/1.1/identifier'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#AnnotationProperty'))
# (rdflib.term.BNode('N21ed62ac8ff64857a655fb0caee997a5'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#first'),
#  rdflib.term.URIRef('http://purl.obolibrary.org/obo/IAO_0000109'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000216'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000356'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#ObjectProperty'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000628'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#ObjectProperty'))
# (rdflib.term.URIRef('http://purl.org/dc/terms/conformsTo'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('conforms to', lang='en'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000793'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#ObjectProperty'))
# (rdflib.term.BNode('N863eee4f514346149043b46b11053794'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#rest'),
#  rdflib.term.BNode('Ne68ce8df19e8417d8466ec117e6420f5'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000628'),
#  rdflib.term.URIRef('http://purl.org/dc/terms/description'),
#  rdflib.term.Literal('refers to is a relation between one entity and the entity that it makes reference to.', lang='en'))
# (rdflib.term.URIRef('http://purl.org/beat-covid/cytokines-semantic-model#beat_covid_id'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_010079'),
#  rdflib.term.URIRef('http://purl.org/dc/terms/description'),
#  rdflib.term.Literal('a relation between two objects, in which the first object is produced from the information contained in the second object.', lang='en'))
# (rdflib.term.URIRef('http://purl.org/dc/terms/Agent'),
#  rdflib.term.URIRef('http://purl.org/dc/terms/description'),
#  rdflib.term.Literal('a resource that acts or has the power to act.', lang='en'))
# (rdflib.term.URIRef('http://purl.org/beat-covid/cytokines-semantic-model.owl'),
#  rdflib.term.URIRef('http://purl.org/dc/terms/description'),
#  rdflib.term.Literal('The cytokine semantic model provides an ontology for integration of health COVID-19 observational data collected in the LUMC hospital for patient monitoring and research.', lang='en'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000356'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subPropertyOf'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#topObjectProperty'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000132'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subPropertyOf'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#topObjectProperty'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_001024'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.BNode('Ne66eddedcb704ef8a48e96c1e4f745da'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#rest'),
#  rdflib.term.BNode('N809dd86ad1e9466e836e178361283588'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000300'),
#  rdflib.term.URIRef('http://purl.org/dc/elements/1.1/identifier'),
#  rdflib.term.Literal('SIO_000300'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/IAO_0000219'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subPropertyOf'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#topObjectProperty'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_010043'),
#  rdflib.term.URIRef('http://purl.org/dc/terms/description'),
#  rdflib.term.Literal('a protein is an organic polymer that is composed of one or more linear polymers of amino acids.', lang='en'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000628'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subPropertyOf'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#topObjectProperty'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000230'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#ObjectProperty'))
# (rdflib.term.URIRef('http://purl.org/beat-covid/cytokines-semantic-model.owl'),
#  rdflib.term.URIRef('http://purl.org/dc/elements/1.1/creator'),
#  rdflib.term.URIRef('http://orcid.org/0000−0002−6844−0067'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/RO_0001025'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#TransitiveProperty'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000139'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#domain'),
#  rdflib.term.URIRef('http://semanticscience.org/resource/SIO_001024'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000356'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#domain'),
#  rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000715'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000793'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subPropertyOf'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#topObjectProperty'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000498'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'),
#  rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000776'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_001289'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'),
#  rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000005'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000642'),
#  rdflib.term.URIRef('http://purl.org/dc/elements/1.1/identifier'),
#  rdflib.term.Literal('SIO_000642'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000992'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('unsupported', lang='en'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000992'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000300'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('has value', lang='en'))
# (rdflib.term.URIRef('http://purl.org/dc/terms/Agent'),
#  rdflib.term.URIRef('http://purl.org/dc/elements/1.1/identifier'),
#  rdflib.term.Literal('Agent'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000688'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('institute', lang='en'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000139'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#ObjectProperty'))
# (rdflib.term.BNode('N07a14dfad75640ebb048fbb18bd03331'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#AllDisjointClasses'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_010043'),
#  rdflib.term.URIRef('http://purl.org/dc/elements/1.1/identifier'),
#  rdflib.term.Literal('SIO_010043'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000132'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#ObjectProperty'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/RO_0002091'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#domain'),
#  rdflib.term.URIRef('http://semanticscience.org/resource/SIO_001049'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_001403'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000672'),
#  rdflib.term.URIRef('http://purl.org/dc/elements/1.1/identifier'),
#  rdflib.term.Literal('SIO_000672'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000992'),
#  rdflib.term.URIRef('http://purl.org/dc/elements/1.1/identifier'),
#  rdflib.term.Literal('SIO_000992'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/RO_0002091'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'),
#  rdflib.term.URIRef('http://purl.obolibrary.org/obo/NCIT_C48906'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000228'),
#  rdflib.term.URIRef('http://purl.org/dc/elements/1.1/identifier'),
#  rdflib.term.Literal('SIO_000228'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_000115'),
#  rdflib.term.URIRef('http://purl.org/dc/terms/description'),
#  rdflib.term.Literal('an identifier is a label that specifically refers to (identifies) an entity (instance/type).', lang='en'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_001292'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://purl.org/beat-covid/cytokines-semantic-model.owl'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Ontology'))
# (rdflib.term.BNode('N1c78f60efa114d6390a5e7ef1b0d71d6'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#rest'),
#  rdflib.term.BNode('N180707e2e19849d0b39b7a90f92b0ae7'))
# (rdflib.term.URIRef('http://semanticscience.org/resource/SIO_001403'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'),
#  rdflib.term.URIRef('http://semanticscience.org/resource/SIO_001211'))

# %% [markdown]
# #### 2. Prepare graph files for Neo4j
#
# __Edges file format__
#
# | s_id:START_ID | p_id:TYPE | o_id:END_ID
#
# other columns:
#    * p_label | p_description | p_uri
#    * reference_uri | reference_sentence | reference_date
#    * evidence_uri | dataset_quality_uri (synthetic/real)
#
#
# __Nodes file format__
#
# | id:ID | :LABEL | label | description | uri
#
# _NB column_name:IGNORE_
# _NULL data as 'NA' (.fill('NA'))
#
# ##### Identifier scheme
#
# We will use the cytokine ontology to provide:
#
#     * edges: id ( p_uri )
#
# We will use the cytokine id mapping file done manually to provide
#
#     * nodes: id ( id:ID | uri )
#
# ##### Semantics
#
# We will use the cytokine ontology to provide:
#
#     * edges: id and type ( p_id:TYPE )
#     * nodes: type ( :LABEL )
#
# We will use the NCIT and CMO ontologies to provide ids for gene, protein, measurement and data measurement nodes.

# %%
# test with a triple from data file
data[:1]
# Out:
#    record_id institute_abbreviation record_creation_date   order  \
# 0  201708869                   LUMC  26-05-2020 15:31:31  BEATVR
#
#   date_sampling  ward  age   beat_id  clinical_id lum_date_meas  ...  \
# 0    08-05-2020  ICUQ   59  BEAT-018    1100207.0    04-05-2020  ...
#
#   lum_sTNFR1_3  lum_sTNFR2_3  lum_TSLP_3 lum_TWEAK_3  lum_IL17F_4 lum_IL21_4  \
# 0          963           263       OOR <         329        OOR <      OOR <
#
#    lum_IL23_4  lum_IL25_4  lum_IL31_4  lum_IL33_4
# 0       OOR <       OOR <       OOR <         597
#
# [1 rows x 141 columns]

# %%
# EDGES
# triple: :process_ has-output :qt_ 
# :process_ (a ncit:IL6 measurement, 
#            dc:conforms-to :kit_) 
# has-output(sio:has-output) 
# :qt_ (a cmo:serum IL6 level, 
#       sio:has-value "12"^^xsd:float, 
#       sio:has-unit uo:pg/ml) 
# :qt_ sio:refers-to ncit:IL6_protein
# ncit:IL6_protein sio:encodes ncit:IL6_gene
edges_l = list()
edge = dict()
base = "http://purl.org/lumc-research/"

# cytokine info: protein name
device, protein_name, kit = 'lum_IL33_4'.split('_')
print("device: {}, cytokine label: {}, kit: {}".format(device, protein_name, kit))
# data records
record_id = str(data.iloc[0,0])
print("recor_id value: {}".format(record_id))
process = 'lum_IL33_4'
print("measurement process: {}".format(process))
# qt value float
qt_value = data['lum_IL33_4'][0]
print("cytokine level value: {}".format(qt_value))

# S :process_ 
# URI:
subject_id_str = "{}-{}".format(record_id,process)
subject_id = "BEATCOVID_" + md5(subject_id_str.encode('utf-8')).hexdigest()
s_uri = rdflib.URIRef(base + subject_id)
print(subject_id,s_uri)

# S type: protein name -> ncit:protein name_measurement

# O :qt_
# URI:
object_id_str = "{}-{}-{}".format(record_id,process,qt_value)
object_id = "BEATCOVID_" + md5(object_id_str.encode('utf-8')).hexdigest()
o_uri = rdflib.URIRef(base + object_id)
print(object_id,o_uri)

# O type: protein name -> cmo:protein name_level


# triple as neo4j edge:  s_id:START_ID | p_id:TYPE | o_id:END_ID
prefix = "lumc:"
# s_id = beat:BEATCOVID_record_measurement_process_hashedidentifier
s_id = prefix + subject_id
# p_id = sio:SIO_id 
has_output = "SIO_000229"
p_id = "sio:" + has_output
# o_id = beat:BEATCOVID_record_measurement_process_qt_hashedidentifier
o_id = prefix + object_id

# df neo4j format
edge[':START_ID'] = s_id
edge[':TYPE'] = p_id
edge[':END_ID'] = o_id
edges_l.append(edge)
df = pd.DataFrame(edges_l)
df
# Out:
# device: lum, cytokine label: IL33, kit: 4
# recor_id value: 201708869
# measurement process: lum_IL33_4
# cytokine level value: 597
# BEATCOVID_da4bbb0d60764bb94b5e48dd8e2eeeae http://purl.org/lumc-research/BEATCOVID_da4bbb0d60764bb94b5e48dd8e2eeeae
# BEATCOVID_15b392e12cd2286030e13cf2f2b98aaf http://purl.org/lumc-research/BEATCOVID_15b392e12cd2286030e13cf2f2b98aaf
#                                          :START_ID           :TYPE  \
# 0  lumc:BEATCOVID_da4bbb0d60764bb94b5e48dd8e2eeeae  sio:SIO_000229
#
#                                            :END_ID
# 0  lumc:BEATCOVID_15b392e12cd2286030e13cf2f2b98aaf

# %%
# create EDGES file 'covid19_statements_v{}.csv'
import datetime, os

# create dir
today = datetime.date.today()
graph_version = 'v{}'.format(today)
neo4j_path = os.getcwd() + '/neo4j'
path_to_import = neo4j_path + '/import' 
path_to_version = neo4j_path + '/import/' + graph_version
if not os.path.isdir(path_to_import): os.makedirs(path_to_import)
if not os.path.isdir(path_to_version): os.makedirs(path_to_version)

    
# create edge file with neo4j format
edges = df.copy()
edges.to_csv('{}/covid19_statements.csv'.format(path_to_import), index=False, na_rep='NA')
edges.to_csv('{}/covid19_statements.csv'.format(path_to_version), index=False, na_rep='NA')

# %%
# test with a triple from data file
data[:1]
# Out:
#    record_id institute_abbreviation record_creation_date   order  \
# 0  201708869                   LUMC  26-05-2020 15:31:31  BEATVR
#
#   date_sampling  ward  age   beat_id  clinical_id lum_date_meas  ...  \
# 0    08-05-2020  ICUQ   59  BEAT-018    1100207.0    04-05-2020  ...
#
#   lum_sTNFR1_3  lum_sTNFR2_3  lum_TSLP_3 lum_TWEAK_3  lum_IL17F_4 lum_IL21_4  \
# 0          963           263       OOR <         329        OOR <      OOR <
#
#    lum_IL23_4  lum_IL25_4  lum_IL31_4  lum_IL33_4
# 0       OOR <       OOR <       OOR <         597
#
# [1 rows x 141 columns]

# %%
# NODES
# | id:ID | :LABEL | label | description | uri
nodes_l = list()
node = dict()
ids = dict()
ids[s_id] = 1
ids[o_id] = 1
print(ids.keys())

# values
# subject
ids[s_id] = {'label': 'ASSAY', 'preflabel': process}

# object
ids[o_id] = {'label': 'MEASUREMENT', 'preflabel': protein_name}

# add 
for node_id in ids.keys():
    node['id:ID'] = node_id
    node[':LABEL'] = ids[node_id]['label']
    node['preflabel'] = ids[node_id]['preflabel']
    nodes_l.append(node)
    node = dict()
# Out:
# dict_keys(['lumc:BEATCOVID_da4bbb0d60764bb94b5e48dd8e2eeeae', 'lumc:BEATCOVID_15b392e12cd2286030e13cf2f2b98aaf'])

# %%
df = pd.DataFrame(nodes_l)
df
# Out:
#                                              id:ID       :LABEL   preflabel
# 0  lumc:BEATCOVID_da4bbb0d60764bb94b5e48dd8e2eeeae        ASSAY  lum_IL33_4
# 1  lumc:BEATCOVID_15b392e12cd2286030e13cf2f2b98aaf  MEASUREMENT        IL33

# %%
# create node file with neo4j format
nodes = df.copy()
nodes.to_csv('{}/covid19_concepts.csv'.format(path_to_import), index=False, na_rep='NA')
nodes.to_csv('{}/covid19_concepts.csv'.format(path_to_version), index=False, na_rep='NA')

# %%
#
